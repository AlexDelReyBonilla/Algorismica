# %% [markdown]
# # Capítol 5 - Dividir i Vèncer

# %% [markdown]
# ### 5.10 Comptador d'inversions

# %% [markdown]
# Volem ordenar una llista A de nombres enters en ordre creixent, es a dir,
# $A[i] < A[j]$ per a qualsevol $i < j$.
#
# Definim inversió, com el procés d'intercanviar dos valors de la llista que no
# estiguin en el seu ordre natural, es a dir, que el de l'esquerra sigui més gran
# que el de la dreta. Concretament, diem que $(A[i];A[j])$ es una inversió, si
# $A[i] > A[j]$ i $i < j$.
#
# Escriu una funció que calculi el nombre d'inversions dins una llista i que digui quines son.
#
# Fes servir aquesta plantilla per escriure el teu codi:

# %%
def comptador_inversions(llista):
    """
    Aquesta funció compta quantes inversions s'han fet.
    
    Parameters
    ----------
    llista: list
    
    Returns
    -------
    num: int
    """
    inversions = 0
    inversiones = 0
    for i in range(0,len(llista)-1):
        for j in range(0,len(llista)-1):
            print("i")
            print(llista[i])
            print("j")
            print(llista[j])
            if llista[i]>llista[j]:
                inversions +=1
                llista[i],llista[j]=llista[j],llista[i]
                print(llista)
                j=0
        
        if i == len(llista) - 1:
            return -1
    return inversiones
print(comptador_inversions([3, 1, 5, 2, 7, 8, 4]))
# Out:
# range(0, 6)
# i
# 3
# j
# 3
# i
# 3
# j
# 1
# [1, 3, 5, 2, 7, 8, 4]
# i
# 1
# j
# 5
# i
# 1
# j
# 2
# i
# 1
# j
# 7
# i
# 1
# j
# 8
# i
# 3
# j
# 1
# [3, 1, 5, 2, 7, 8, 4]
# i
# 1
# j
# 1
# i
# 1
# j
# 5
# i
# 1
# j
# 2
# i
# 1
# j
# 7
# i
# 1
# j
# 8
# i
# 5
# j
# 3
# [5, 1, 3, 2, 7, 8, 4]
# i
# 3
# j
# 1
# [5, 3, 1, 2, 7, 8, 4]
# i
# 1
# j
# 1
# i
# 1
# j
# 2
# i
# 1
# j
# 7
# i
# 1
# j
# 8
# i
# 2
# j
# 5
# i
# 2
# j
# 3
# i
# 2
# j
# 1
# [5, 3, 2, 1, 7, 8, 4]
# i
# 1
# j
# 1
# i
# 1
# j
# 7
# i
# 1
# j
# 8
# i
# 7
# j
# 5
# [7, 3, 2, 1, 5, 8, 4]
# i
# 5
# j
# 3
# [7, 5, 2, 1, 3, 8, 4]
# i
# 3
# j
# 2
# [7, 5, 3, 1, 2, 8, 4]
# i
# 2
# j
# 1
# [7, 5, 3, 2, 1, 8, 4]
# i
# 1
# j
# 1
# i
# 1
# j
# 8
# i
# 8
# j
# 7
# [8, 5, 3, 2, 1, 7, 4]
# i
# 7
# j
# 5
# [8, 7, 3, 2, 1, 5, 4]
# i
# 5
# j
# 3
# [8, 7, 5, 2, 1, 3, 4]
# i
# 3
# j
# 2
# [8, 7, 5, 3, 1, 2, 4]
# i
# 2
# j
# 1
# [8, 7, 5, 3, 2, 1, 4]
# i
# 1
# j
# 1
# 0

# %%
assert comptador_inversions([3, 1, 5, 2, 7, 8, 4]) == 6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 assert comptador_inversions([3, 1, 5, 2, 7, 8, 4]) == 6
#
# NameError: name 'comptador_inversions' is not defined
